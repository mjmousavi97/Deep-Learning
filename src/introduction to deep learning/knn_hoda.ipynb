# %%
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import numpy as np

from load_dataset_hoda import load_hoda

# %%
x_train, y_train, x_test, y_test = load_hoda(data_path="", train_size=1000, test_size=200, img_size=(5, 5))

print(f"Shape of x train: {x_train.shape}")
print(f"Shape of x test: {x_test.shape}")

print(f"Shape of y train: {y_train.shape}")
print(f"Shape of y test: {y_test.shape}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\Mousavi\anaconda3\envs\psychopy_env\lib\site-packages\scipy\io\matlab\_mio.py:39, in _open_file(file_like, appendmat, mode)
#      38 try:
# ---> 39     return open(file_like, mode), True
#      40 except OSError as e:
#      41     # Probably "not found"
#
# FileNotFoundError: [Errno 2] No such file or directory: ''
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x_train, y_train, x_test, y_test = load_hoda(data_path="", train_size=1000, test_size=200, img_size=(5, 5))
#       3 print(f"Shape of x train: {x_train.shape}")
#       4 print(f"Shape of x test: {x_test.shape}")
#
# ...

# %%
neigh_clf = KNeighborsClassifier(n_neighbors=3)
neigh_clf.fit(X=x_train, y=y_train)

# %%
sample = 25
x_sample = [x_test[sample]]
prediction_sample = neigh_clf.predict(x_sample)
print(f"Sample {sample} is a {y_test[sample]} and model prediction is: {prediction_sample}.")

# %%
print(neigh_clf.predict_proba(x_sample))

# %%
y_pred = neigh_clf.predict(x_test)

# %%
print(f"Accuracy is: {np.mean(y_pred == y_test)*100}")
print(f"Accuracy is: {neigh_clf.score(x_test, y_test)*100}")

# %% [markdown]
# -----
