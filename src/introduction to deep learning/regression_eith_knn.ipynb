# %%
import mglearn
import numpy as np
import matplotlib.pyplot as plt

# %%
mglearn.plot.plot_knn_regression(n_neighbors=1)

# %%
mglearn.plt.plot_knn_regression(n_neighbors=2)

# %%
mglearn.plot.plot_knn_regression(n_neighbors=3)

# %%
x, y = mglearn.dataset.make_wave(n_sample=40)

plt.plot(x, y, 'o')
plt.ylim(-3, 3)
plt.xlabel("Feature")
plt.ylabel("Target")

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42)

print(f"Shape of x train: {x_train.shape}")
print(f"Shape of x test: {x_test.shape}")

reg_knn = KNeighborsRegressor(n_neighbors=3)
reg_knn.fit(X=x_train, y=y_train)

# %%
reg_knn.predict(X=x_test)

# %%
reg_knn.score(X=x_test, y=y_test)
